# %% [markdown]
# # Twitter Messages Data Analysis
# Code link: https://github.com/hennypurwadi/twitter_analysis

# %% [markdown]
# ### Collect Tweets from particular geocode location in Google map
# https://www.google.com/maps/place/Taiwan/@24.8953179,121.5280722,10.25z/data=!4m5!3m4!1s0x346ef3065c07572f:0xe711f004bf9c5469!8m2!3d23.69781!4d120.960515

# %%
# !pip3 install snscrape
# !pip install tweepy
# !pip install wordcloud
# !pip install warnings-plugin

# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import os
import re
import string
import snscrape.modules.twitter as sntwitter
import tweepy
import unicodedata
import random
import sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import NMF
from wordcloud import WordCloud, STOPWORDS
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.util import bigrams
from nltk.util import trigrams
from nltk.util import ngrams
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\ProgramData\Anaconda3\envs\DLBDSEDA02\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Asus\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# ### Collect Tweets Without Twitter Developer Account /API: with snscrape

# %% [markdown]
# #
# ![Taipei_map.jpg](attachment:Taipei_map.jpg)

# %%
#Create and append to csv file and then write tweets into csv file
tweet_data = open('Taipei_tweets_sns.csv', 'a', newline='', encoding='utf8')
csv.writer(tweet_data).writerow(['username','tweet','hashtags']) 

#Radius around 50 km around particular geocode
max_tweets = 40000
for n,tweet in enumerate(sntwitter.TwitterSearchScraper('geocode:25.07588,121.54539,50km \
        + since:2022-08-01 until:2022-08-05 lang:en -filter:links -filter:replies').get_items()):
    
    if n > max_tweets:
        break
    csv.writer(tweet_data).writerow([tweet.user.username, tweet.content, tweet.hashtags])      
tweet_data.close()

# %%
df = pd.read_csv('Taipei_tweets_sns.csv')
df = df.dropna(subset = ['hashtags']) #Only use tweets which contained hashtags
df.head()
# Out:
#         username                                              tweet  \
# 4   RudolfEmily3  1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9       fipsyfip  Musk says that that the only two publicly trad...
# 11   SHIBUYAENNI  This account is Tweetbot, I don't use it. #Twe...
# 16      fipsyfip  #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17      fipsyfip  #tesla #TSLA Musk says there’s still a “host o...
#
#              hashtags
# 4     ['kingmessiah']
# 9           ['tesla']
# 11       ['Tweetbot']
# 16  ['Tesla', 'TSLA']
# 17  ['tesla', 'TSLA']

# %%
len(df)
# Out:
# 293

# %% [markdown]
# ### Remove emojis from username
# Can't clean username like make Capital letter become lowercase etc, since Capital letter etc is unique part of the name.
#
# Only remove emojis from username.

# %%
emoji_pattern = re.compile("["
                        "\U0001F600-\U0001F64F"  # emoticons
                        "\U0001F1E0-\U0001F1FF"  # flags (iOS)
                        "\U0001F300-\U0001F5FF"  # pictographs, symbols 
                        "\U0001F700-\U0001F77F"  # alchemical symbols
                        "\U0001F680-\U0001F6FF"  # transport & map symbols
                        "\U0001FA00-\U0001FA6F"  # Chess Symbols
                        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
                        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
                        "\U00002702-\U000027B0"  # Dingbats
                        "\U0001F1E0-\U0001F1FF"  # flags (iOS)   
                        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
                        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs                        
                        "\U000024C2-\U0001F251" 
                        "]+", flags=re.UNICODE)  

def delete_emoji(string):
    return emoji_pattern.sub(r'', string)

df['username_no_emoji'] = df['username'].apply(delete_emoji)
df[['username','username_no_emoji']].head()
# Out:
#         username username_no_emoji
# 4   RudolfEmily3      RudolfEmily3
# 9       fipsyfip          fipsyfip
# 11   SHIBUYAENNI       SHIBUYAENNI
# 16      fipsyfip          fipsyfip
# 17      fipsyfip          fipsyfip

# %% [markdown]
# ## 1. Entity analysis to find 5 most active users.

# %%
#df['user'].unique()
userlist = df['username_no_emoji'].value_counts()
most_active_users = userlist.head(5)
most_active_users
# Out:
# YimouLee          24
# WilliamYang120    24
# tmj_twn_jobs      14
# fipsyfip          13
# SHIBUYAENNI       11
# Name: username_no_emoji, dtype: int64

# %%
plot_users=most_active_users.plot.pie(autopct='%1.1f%%', figsize=(5, 5))
plt.rc('axes', unicode_minus=False)
plt.savefig("MostActiveUser_chart.jpeg",transparent=False, bbox_inches='tight',pad_inches=0.1)

# %% [markdown]
# ## 2. Entity analysis to find 5 most used hastags

# %% [markdown]
# ### Lite Cleaning for hashtags
# Cleaning hashtags to get 5 most prevalent ones is lite cleaning

# %%
#Functun to convert to str
def lightclean(hashtags_data):  
    hashtags_data = str(hashtags_data).lower() #make str
    return hashtags_data

df['Cleaned_Hashtags'] = df['hashtags'].apply(lightclean)

htag_Texts_Cleaned=df['Cleaned_Hashtags'].values
htag_Texts_Cleaned=str(htag_Texts_Cleaned)
htag_Texts_Cleaned = re.sub(r'[^a-z A-Z]', ' ',htag_Texts_Cleaned)
htag_Texts_Cleaned= re.sub(r' +', ' ', htag_Texts_Cleaned)
htag_Texts_Cleaned= re.sub(r' text', ' ', htag_Texts_Cleaned) #remove 'text'
htag_Texts_Cleaned= re.sub(r' indices', ' ', htag_Texts_Cleaned) #remove 'indices'
print("Cleaned hashtags:" + "\n" + htag_Texts_Cleaned)
# Out:
# Cleaned hashtags:
#  kingmessiah tesla tweetbot tesla tsla tesla tsla tsla tesla tesla tsla tesla tsla tesla tsla codinglife softwareengineer devlog life coding coffeelover tesla tsla tesla tsla tesla tsla tesla tsla tesla tsla tesla tsla seneca stoicism chinataiwancrisis nancypelosi breaking swift android twitter china america taiwan taiwanchinaconflict taiwancivilianwanttosay newprofilepic nftcommmunity ecommerce blocked taiwan taiwan taiwan langtwt taiwan rootmeta lit blocked qanda qanda qanda china taiwan qanda twitter tweets qanda qanda tinagoldsteinmonth qanda taiwan taiwan taiwan abc taiwan us china taiwan metaverse playtoearn nfts alessandropertiniyou marcusaurelius stoicism taiwan china semiconductors china taiwan taiwan taiwan tweetbot nannystate overstep taiwan taiwanstraitscrisis taipei engineering thetrad innergame mindfulness milebiblexemiliopucci lp liquidity breaking engineering taipei taiwan taiwan taiwan taiwan taiwan fear fear fearofgod fear china taiwan taiwan taipei engineering rocarmdforces krotime eternals eternals shangchi phase deathstranding sol solgiveaway solana g taiwan tweetbot supplychain giveaway taiwan taiwan ccp taiwan faunline taiwan langtwt taiwan svs ukilive taiwan wingnight crypto nft tweetbot giveaway bn rollomay stoicism swift xcode mystalive nftgiveaway extraordinaryattorneywooep extraordinaryattorneywoo extraordinaryattorneywooep extraordinaryattorneywoo pelosi taiwan canada france germany italy japan uk us eu taiwanstrait taiwan youtube ads socialmedia jimin audacyaots daysofswiftui tweetstorm chinataiwancrisis pelosi milkteaalliance taiwan mystalive taiwan taiwan taiwan taiwan taiwan taiwan tweetbot guerrilla ndwin guerrilla movement ateez guerrilla ateez movement ateez bayc apecoin taiwan tinagoldsteinmonth bitcoin taiwan nancypelosi taiwan taiwan taipei engineering blocked marcusaurelius stoicism sales taipei taiwan langtwt engineering hsinchu tsaiingwen nancypelosi pelosi taiwan taiwan pelosi chips chips engineering taipei taiwan cnn china cobbisbest china taiwan tweetbot video legendofzelda ds youtube retrogaming gaming zelda nintendo twitterversary bbnaija bbnaijaseason bbnaijas firstkilldeservesbetter lesbiansdeservebetter firstkill taiwan pelosi taiwan china pelosi taiwancanhelp dbacks taiwan taiwan expopulus dags finalform pelosi chips taiwan supplychain china taiwan taiwan taiwan covid rocmnd taiwan nancypelosi taiwan vesperonline cardano tweetbot taiwan langtwt dbacks taiwan kinmen endgerontocracy marcusaurelius stoicism taiwan taiwan taipei pelosi taiwan taiwan taiwanisnotchina taiwan china pelosi taiwan pelosi taiwan speakernancypelosi taiwan china taiwan pelosi pelosi taiwan taiwan pelosi taiwan azgov daysofswiftui taiwan taiwanisnotchina taiwan peacefultaiwan spar zeepruk taiwan pelosi taiwan taipei china beijing happygirlfriendsday editbutton taiwan ddos beijing pelosi langtwt cats catsoftwittter catlover taipei taiwan pelosi taiwan voxpopulive taiwan taiwan pelosi pelositaiwan taiwan nancypelosi us taiwan spar grandhyatt taipei republicofchina pelosi pelosivisit pelositaiwan nancypelositaiwan pelosileaveasia china taiwan taiwan drawing art langtwt cobbisbest twitter pelosi taiwan langtwt taiwan ukraine china marcusaurelius stoicism spar spar pelosi tweetbot taiwanese engineering hsinchu taiwan mcu wakanda pelosivisitstaiwan hongkongdemocracyprotest nightmare hololive forwardparty productmgmt editbutton taiwan taiwan taiwan china taiwan unity d nocode astrogate collaboration workplaces classrooms voxpopulive voxasmr dbacks tweetbot rollomay stoicism coding swift development taiwan pelosi pelosivisittotaiwan wynncraft tsmc pelosi happymarkday remarkable years happymarkday remarkble years pelosi voxpopulive taiwan tweetbot history audible audiobook europe philosophy taiwan shinethroughgoodworks mcgicares shinethroughgoodworks mcgicares shinethroughgoodworks mcgicares bullettrain taiwan marcusaurelius stoicism pelosi taiwan us taiwan china taiwan china qt blocked hsinchu costco lifehacks bil ...

# %% [markdown]
# ### Counting the number of hastags

# %%
def word_count(str):
    counts = dict()
    words = str.split()

    for word in words:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts

hashtag_count = word_count(htag_Texts_Cleaned)
print(hashtag_count)
# Out:
# {'kingmessiah': 1, 'tesla': 13, 'tweetbot': 11, 'tsla': 12, 'codinglife': 1, 'softwareengineer': 1, 'devlog': 1, 'life': 1, 'coding': 2, 'coffeelover': 1, 'seneca': 1, 'stoicism': 8, 'chinataiwancrisis': 2, 'nancypelosi': 5, 'breaking': 2, 'swift': 3, 'android': 1, 'twitter': 3, 'china': 18, 'america': 1, 'taiwan': 102, 'taiwanchinaconflict': 1, 'taiwancivilianwanttosay': 1, 'newprofilepic': 1, 'nftcommmunity': 1, 'ecommerce': 1, 'blocked': 4, 'langtwt': 7, 'rootmeta': 1, 'lit': 1, 'qanda': 7, 'tweets': 1, 'tinagoldsteinmonth': 2, 'abc': 1, 'us': 4, 'metaverse': 1, 'playtoearn': 1, 'nfts': 1, 'alessandropertiniyou': 1, 'marcusaurelius': 5, 'semiconductors': 1, 'nannystate': 1, 'overstep': 1, 'taiwanstraitscrisis': 1, 'taipei': 13, 'engineering': 8, 'thetrad': 1, 'innergame': 1, 'mindfulness': 1, 'milebiblexemiliopucci': 1, 'lp': 1, 'liquidity': 1, 'fear': 3, 'fearofgod': 1, 'rocarmdforces': 1, 'krotime': 1, 'eternals': 2, 'shangchi': 1, 'phase': 1, 'deathstranding': 1, 'sol': 1, 'solgiveaway': 1, 'solana': 1, 'g': 1, 'supplychain': 2, 'giveaway': 2, 'ccp': 1, 'faunline': 1, 'svs': 1, 'ukilive': 1, 'wingnight': 1, 'crypto': 1, 'nft': 1, 'bn': 1, 'rollomay': 2, 'xcode': 1, 'mystalive': 2, 'nftgiveaway': 1, 'extraordinaryattorneywooep': 2, 'extraordinaryattorneywoo': 2, 'pelosi': 24, 'canada': 1, 'france': 1, 'germany': 1, 'italy': 1, 'japan': 1, 'uk': 1, 'eu': 1, 'taiwanstrait': 1, 'youtube': 2, 'ads': 1, 'socialmedia': 1, 'jimin': 1, 'audacyaots': 1, 'daysofswiftui': 2, 'tweetstorm': 1, 'milkteaalliance': 1, 'guerrilla': 3, 'ndwin': 1, 'movement': 2, 'ateez': 3, 'bayc': 1, 'apecoin': 1, 'bitcoin': 1, 'sales': 1, 'hsinchu': 4, 'tsaiingwen': 1, 'chips': 3, 'cnn': 1, 'cobbisbest': 2, 'video': 1, 'legendofzelda': 1, 'ds': 1, 'retrogaming': 1, 'gaming': 1, 'zelda': 1, 'nintendo': 1, 'twitterversary': 1, 'bbnaija': 1, 'bbnaijaseason': 1, 'bbnaijas': 1, 'firstkilldeservesbetter': 1, 'lesbiansdeservebetter': 1, 'firstkill': 1, 'taiwancanhelp': 1, 'dbacks': 3, 'expopulus': 1, 'dags': 1, 'finalform': 1, 'covid': 1, 'rocmnd': 1, 'vesperonline': 1, 'cardano': 1, 'kinmen': 1, 'endgerontocracy': 1, 'taiwanisnotchina': 2, 'speakernancypelosi': 1, 'azgov': 1, 'peacefultaiwan': 1, 'spar': 4, 'zeepruk': 1, 'beijing': 2, 'happygirlfriendsday': 1, 'editbutton': 2, 'ddos': 1, 'cats': 1, 'catsoftwittter': 1, 'catlover': 1, 'voxpopulive': 3, 'pelositaiwan': 2, 'grandhyatt': 1, 'republicofchina': 1, 'pelosivisit': 1, 'nancypelositaiwan': 1, 'pelosileaveasia': 1, 'drawing': 1, 'art': 1, 'ukraine': 1, 'taiwanese': 1, 'mcu': 1, 'wakanda': 1, 'pelosivisitstaiwan': 1, 'hongkongdemocracyprotest': 1, 'nightmare': 1, 'hololive': 1, 'forwardparty': 1, 'productmgmt': 1, 'unity': 1, 'd': 1, 'nocode': 1, 'astrogate': 2, 'collaboration': 1, 'workplaces': 1, 'classrooms': 1, 'voxasmr': 1, 'development': 1, 'pelosivisittotaiwan': 1, 'wynncraft': 1, 'tsmc': 1, 'happymarkday': 2, 'remarkable': 1, 'years': 2, 'remarkble': 1, 'history': 1, 'audible': 1, 'audiobook': 1, 'europe': 1, 'philosophy': 1, 'shinethroughgoodworks': 3, 'mcgicares': 3, 'bullettrain': 1, 'qt': 1, 'costco': 1, 'lifehacks': 1, 'billrussellrip': 1, 'onevine': 1, 'hobipalooza': 4, 'rinkeby': 1, 'ethereum': 1, 'mss': 1, 'nddebutanniv': 1, 'yilan': 1, 'hualien': 1, 'taitung': 1, 'newtaipei': 1, 'taoyuan': 1, 'keepcoolandcarryon': 1, 'jackinthebox': 2, 'jhopeatlollapalooza': 2, 'businessmgmt': 1, 'nostormdays': 1, 'carryon': 1, 'simlpifyyourlife': 1, 'work': 1, 'internship': 1}

# %%
import matplotlib.pyplot as plt
fig, ax1 = plt.subplots(figsize=(20, 6))
ax1.bar(hashtag_count.keys(), hashtag_count.values())
fig.autofmt_xdate()
plt.savefig('hashtag_count_graph.jpeg')
plt.show()

# %%
MostPopularHashtags = sorted(hashtag_count, key=hashtag_count.get, reverse=True)[:5]
#' '.join(MostPopularHashtags)
MostPopularHashtags
# Out:
# ['taiwan', 'pelosi', 'china', 'tesla', 'taipei']

# %%
#Convert list to str

MostPopularHashtags_str = ''
i = 0
for x in MostPopularHashtags:
    i = i+1
    if i < 5:
        MostPopularHashtags_str += '#'+ x + ', '
    else:
        MostPopularHashtags_str += '#'+ x
    
print("5 Most popular hastags are : " + MostPopularHashtags_str)
# Out:
# 5 Most popular hastags are : #taiwan, #pelosi, #china, #tesla, #taipei

# %%
TopPopularHashtags = sorted(hashtag_count, key=hashtag_count.get, reverse=True)[:1]
TopPopularHashtags_str = ' '.join(str(e) for e in TopPopularHashtags) #convert list to str
TopPopularHashtags_str
print("Top popular hastags is : " + TopPopularHashtags_str)
# Out:
# Top popular hastags is : taiwan

# %% [markdown]
# ## 3. Entity analysis to extract five most prevalent topics in the tweets

# %% [markdown]
# ### Preprocessing, Cleaning with regex
# Make the text lowercase, remove line breaks, punctuation, usernames, url, extra spaces, etc

# %%
def cleaning(tweets_data):   
    tweets_data = str(tweets_data).lower() #Make the text lowercase.
    tweets_data = re.sub(r'#[A-Za-z0–9]+', '', tweets_data) #remove hashtags
    tweets_data=re.sub(r'@[A-Za-z0–9]+', '',tweets_data) #remove usernames    
    tweets_data=re.sub(r'@\w+', ' ', tweets_data) #remove usernames
    tweets_data= re.sub(r'\b\w{1}\b', '', tweets_data) #remove stopwords   
    tweets_data = re.sub(r'&(?![A-Za-z]+[0-9]*;|#[0-9]+;|#x[0-9a-fA-F]+;)', '', tweets_data)
    tweets_data = re.sub(r'&amp', '', tweets_data) 
    tweets_data = re.sub('\n', '', tweets_data) #Remove line breaks.
    tweets_data = re.sub('[%s]' % re.escape(string.punctuation), '', tweets_data) #remove punctuation
    tweets_data = re.sub('\[.*?\]', '', tweets_data)
    tweets_data=re.sub(r'http\S+', ' ', tweets_data) #remove all Url
    tweets_data = re.sub(r'https?:\/\/.*[\r\n]*', '', tweets_data) #remove website
    tweets_data = re.sub('https?://\S+|www\.\S+', '', tweets_data)  #remove all websites 
    tweets_data = re.sub(r' +', ' ', tweets_data) #remove extra space
    tweets_data = re.sub('<.*?>+', '', tweets_data)    
    tweets_data = re.sub('\w*\d\w*', '', tweets_data)
    tweets_data = re.sub(r'^RT[\s]+', '', tweets_data)    
    tweets_data = re.sub(r'[^a-z A-Z]', ' ',tweets_data) #Remove all not characters
    tweets_data = re.sub(emoji_pattern, '', tweets_data)#remove emojis
          
    return tweets_data

df['clean1_tweet'] = df['tweet'].apply(cleaning)
df_cleaned_tweets=df[['tweet','clean1_tweet']]
df_cleaned_tweets.head(20)
# Out:
#                                                 tweet  \
# 4   1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9   Musk says that that the only two publicly trad...
# 11  This account is Tweetbot, I don't use it. #Twe...
# 16  #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17  #tesla #TSLA Musk says there’s still a “host o...
# 18  #TSLA #Tesla Musk says that the Model Y is tra...
# 19  #tesla #TSLA Elon Musk is now on stage and say...
# 20  #tesla #TSLA Viecha announces preliminary resu...
# 21  #tesla #TSLA Tesla Holders Approve 3-to-1 Stoc...
# 27  🌞☕️👩🏻‍💻\nMornings are for coffee and coding.\n...
# 28  #tesla #TSLA Proposal 8 requests that Tesla re...
# 29  #tesla #TSLA “Let’s cut the bull,” McRitchie s...
# 30  #tesla #TSLA Martin Viecha is now officially c...
# 32  #tesla #TSLA Denholm says that “good governanc...
# 34  #tesla #TSLA Denholm is stressing that Tesla u...
# 35  Tesla Inc Viecha says Musk will give a “presen...
# 48  Whatever can happen at any time can happen tod...
# 54  China wants to annex Taiwan and yet Chinese go...
# 65  #BREAKING: JUST IN - China flew its drones (BZ...
# 68  Need tackle VIPER today for the first time…goo...
#
#                                          clean1_tweet
# 4    sheesherc kingmessiahbsc bro that coin is res...
# 9   musk says that that the only two publicly trad...
# 11               this account is tweetbot don use it
# 16    ultimately think we ll end up building  or  ...
# 17   musk says there  still  host of problems  lef...
# 18   musk says that the model is tracking to be te...
# 19   elon musk is now on stage and says tesla  mig...
# 20   viecha announces preliminary results and the ...
# 21   tesla holders approve to stock split at share...
# 27                mornings are for coffee and coding
# 28   proposal requests that tesla report on its ef...
# 29    let  cut the bull  mcritchie says proxy acce...
# 30   martin viecha is now officially calling the m...
# 32   denholm says that  good governance is hallmar...
# 34   denholm is stressing that tesla uses less wat...
# 35  tesla inc viecha says musk will give  presenta...
# 48  whatever can happen at any time can happen today
# 54  china wants to annex taiwan and yet chinese go...
# 65   just in china flew its drones  and  around ja...
# 68  need tackle viper today for the first time goo...

# %% [markdown]
# ### Remove stopwords with nltk

# %%
stopwords = nltk.corpus.stopwords.words('english') 
df['clean2_tweet'] = df['clean1_tweet'].apply(
    lambda x: " ".join(x for x in x.split() if x not in stopwords))

df_cleaned_tweets=df[['tweet','clean2_tweet']]
df_cleaned_tweets.head()
# Out:
#                                                 tweet  \
# 4   1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9   Musk says that that the only two publicly trad...
# 11  This account is Tweetbot, I don't use it. #Twe...
# 16  #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17  #tesla #TSLA Musk says there’s still a “host o...
#
#                                          clean2_tweet
# 4   sheesherc kingmessiahbsc bro coin respectfly l...
# 9   musk says two publicly traded securities owns ...
# 11                               account tweetbot use
# 16  ultimately think end building gigafactories mu...
# 17  musk says still host problems left solve spool...

# %% [markdown]
# ### Stemming with nltk

# %%
stm = PorterStemmer()
df['clean3_tweet'] = df['clean2_tweet'].apply(
    lambda x: " ".join([stm.stem(word) for word in x.split()]))

df_cleaned_tweets=df[['tweet','clean3_tweet']]
df_cleaned_tweets.head()
# Out:
#                                                 tweet  \
# 4   1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9   Musk says that that the only two publicly trad...
# 11  This account is Tweetbot, I don't use it. #Twe...
# 16  #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17  #tesla #TSLA Musk says there’s still a “host o...
#
#                                          clean3_tweet
# 4   sheesherc kingmessiahbsc bro coin respectfli l...
# 9   musk say two publicli trade secur own tesla tw...
# 11                               account tweetbot use
# 16  ultim think end build gigafactori musk say cla...
# 17  musk say still host problem left solv spool au...

# %% [markdown]
# ### Lemitization with nltk

# %%
##lemmatization to bring the words in their root form  
lem = WordNetLemmatizer()
df['cleaned_tweet'] = df['clean3_tweet'].apply(
    lambda x: " ".join([lem.lemmatize(word) for word in x.split()]))
df_cleaned_tweets=df[['tweet','cleaned_tweet']]
df_cleaned_tweets.head()
# Out:
#                                                 tweet  \
# 4   1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9   Musk says that that the only two publicly trad...
# 11  This account is Tweetbot, I don't use it. #Twe...
# 16  #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17  #tesla #TSLA Musk says there’s still a “host o...
#
#                                         cleaned_tweet
# 4   sheesherc kingmessiahbsc bro coin respectfli l...
# 9   musk say two publicli trade secur own tesla tw...
# 11                               account tweetbot use
# 16  ultim think end build gigafactori musk say cla...
# 17  musk say still host problem left solv spool au...

# %% [markdown]
# ### Vectorize cleaned tweets with CountVectorizer with ngrame_range
#
# ngram_range of (1, 1) means only unigrams.
# (1, 2) means unigrams and bigrams.
# (1, 3) means unigrams, bigrams, and trigrams.
# (2, 2) means only bigrams.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html

# %%
countv = CountVectorizer(min_df=1,max_df=0.95,ngram_range=(1,3),stop_words='english')
countv_tweet = countv.fit_transform(df['cleaned_tweet'])
countv_tweet
# Out:
# <293x6702 sparse matrix of type '<class 'numpy.int64'>'
# 	with 8732 stored elements in Compressed Sparse Row format>

# %%
countv_tweet.shape
# Out:
# (293, 6702)

# %% [markdown]
# ### Vectorize cleaned tweets with Tf-IDF with ngram_range

# %%
tfidf = TfidfVectorizer(min_df=1 ,max_df=0.95, ngram_range=(1,3),stop_words='english')
tfidf_tweet = tfidf.fit_transform(df['cleaned_tweet'])
tfidf_tweet
# Out:
# <293x6702 sparse matrix of type '<class 'numpy.float64'>'
# 	with 8732 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Topic extraction with LDA (Latent Dirichlet Allocation) with Countvectorizer

# %%
LDA_countv = LatentDirichletAllocation(n_components=5,random_state=42)
LDA_countv.fit(countv_tweet)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
#len(LDA_countv.components_[0])
LDA_countv.components_
# Out:
# array([[1.19999772, 1.19999772, 1.19999772, ..., 1.19999587, 1.19999587,
#         1.19999706],
#        [0.20000069, 0.20000069, 0.20000069, ..., 0.20000125, 0.20000125,
#         0.20000088],
#        [0.20000053, 0.20000053, 0.20000053, ..., 0.20000097, 0.20000097,
#         0.20000069],
#        [0.20000057, 0.20000057, 0.20000057, ..., 0.20000103, 0.20000103,
#         0.20000073],
#        [0.20000049, 0.20000049, 0.20000049, ..., 0.20000089, 0.20000089,
#         0.20000063]])

# %%
eachtopic = LDA_countv.components_[0]
eachtopic.argsort()
# Out:
# array([2054,  447, 3173, ..., 2787, 3490, 5539], dtype=int64)

# %%
#eachtopic[183]
# Top 5 words for this topic:
eachtopic.argsort()[-5:]
# Out:
# array([2810, 6242, 2787, 3490, 5539], dtype=int64)

# %%
word_top = eachtopic.argsort()[-5:]
for index in word_top:
    print(countv.get_feature_names()[index])
# Out:
# know
# use
# keyword
# ministri
# taiwan

# %%
for index,topic in enumerate(LDA_countv.components_):
    print(f'Most prevalent topic #{index}'+ ': ')
    print([countv.get_feature_names()[i] for i in topic.argsort()[-10:]])
# Out:
# Most prevalent topic #0:
# ['come', 'like', 'need', 'drill', 'report', 'know', 'use', 'keyword', 'ministri', 'taiwan']
# Most prevalent topic #1:
# ['shibuyaennithat', 'account', 'realli', 'use', 'learn', 'like', 'taiwan', 'china', 'look', 'love']
# Most prevalent topic #2:
# ['think', 'ministri', 'receiv', 'chine', 'year', 'peopl', 'say', 'twitter', 'china', 'taiwan']
# Most prevalent topic #3:
# ['countri', 'job like', 'appli', 'trade', 'follow', 'china', 'job', 'like', 'twitter', 'taiwan']
# Most prevalent topic #4:
# ['day', 'line', 'sourc', 'chine', 'friend', 'visit', 'time', 'pelosi', 'twitter', 'taiwan']

# %%
topic_lda_cv = LDA_countv.transform(countv_tweet)
topic_lda_cv[0].argmax()
topic_lda_cv.argmax(axis=1)
df['Topic_lda_cv'] = topic_lda_cv.argmax(axis=1)
df[['tweet','cleaned_tweet','Topic_lda_cv']].head(40)
# Out:
#                                                  tweet  \
# 4    1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9    Musk says that that the only two publicly trad...
# 11   This account is Tweetbot, I don't use it. #Twe...
# 16   #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17   #tesla #TSLA Musk says there’s still a “host o...
# 18   #TSLA #Tesla Musk says that the Model Y is tra...
# 19   #tesla #TSLA Elon Musk is now on stage and say...
# 20   #tesla #TSLA Viecha announces preliminary resu...
# 21   #tesla #TSLA Tesla Holders Approve 3-to-1 Stoc...
# 27   🌞☕️👩🏻‍💻\nMornings are for coffee and coding.\n...
# 28   #tesla #TSLA Proposal 8 requests that Tesla re...
# 29   #tesla #TSLA “Let’s cut the bull,” McRitchie s...
# 30   #tesla #TSLA Martin Viecha is now officially c...
# 32   #tesla #TSLA Denholm says that “good governanc...
# 34   #tesla #TSLA Denholm is stressing that Tesla u...
# 35   Tesla Inc Viecha says Musk will give a “presen...
# 48   Whatever can happen at any time can happen tod...
# 54   China wants to annex Taiwan and yet Chinese go...
# 65   #BREAKING: JUST IN - China flew its drones (BZ...
# 68   Need tackle VIPER today for the first time…goo...
# 69   #Android #Twitter When the preferred language ...
# 76   The conflict is it a game between #China and #...
# 83   #NewProfilePic ✌️😎✅ Co-gather our amazing #NFT...
# 84   #blocked An international friend on Twitter ha...
# 109  Enjoyed chatting with @chrislindsay_ and @BBCN...
# 133  Responding to mounting public concern on wheth...
# 137  BREAKING -- #Taiwan says fired flares to drive...
# 152  This year marks the 27th year of my language l...
# 164  Prior to US House Speaker Nancy Pelosi’s visit...
# 183  #rootmeta the first Community&amp;amp;Content ...
# 196  Reading w/ care depends on your breadth of exp...
# 206  #blocked Why do some users on Twitter block ot...
# 209  Does the CSIRO dude have a prop for every ques...
# 210  Everytime I here AI, I think of Skynet. Bloody...
# 211  Here's a crazy idea. Find out how much $ NDIS ...
# 213  #China fired missiles into the waters near #Ta...
# 215  How soon before someone brings the idea, "when...
# 216  #Twitter #Tweets Why are some people on Twitte...
# 217  Of course, the guy who has ties to Uranium wil...
# 218  I'm so used to being gaslit, that I keep expec...
#
#                                          cleaned_tweet  Topic_lda_cv
# 4    sheesherc kingmessiahbsc bro coin respectfli l...             0
# 9    musk say two publicli trade secur own tesla tw...             3
# 11                                account tweetbot use             2
# 16   ultim think end build gigafactori musk say cla...             4
# 17   musk say still host problem left solv spool au...             0
# 18   musk say model track tesla highestsel vehicl r...             2
# 19   elon musk stage say tesla might get close mill...             2
# 20   viecha announc preliminari result stock split ...             2
# 21      tesla holder approv stock split sharehold meet             2
# 27                                     morn coffe code             0
# 28   propos request tesla report effort enhanc boar...             4
# 29   let cut bull mcritchi say proxi access long ov...             2
# 30   martin viecha offici call meet order peopl alr...             1
# 32   denholm say good govern hallmark sustain menti...             0
# 34   denholm stress tesla use le water factori auto...             0
# 35   tesla inc viecha say musk give present propos ...             3
# 48                     whatev happen time happen today             3
# 54   china want annex taiwan yet chine gov often sp...             2
# 65   china flew drone around japan sakishima island...             4
# 68         need tackl viper today first time good luck             0
# 69   prefer languag twitter android client simplifi...             4
# 76   conflict game poor toyand taiwanes wait player...             4
# 83      cogath amaz elrondcombey fundament chang nftac             4
# 84   intern friend twitter block almost month inter...             4
# 109                          enjoy chat develop situat             2
# 133  respond mount public concern whether chine mis...             2
# 137  break say fire flare drive away four drone kin...             4
# 152  year mark year languag learn effort learn stil...             2
# 164  prior u hous speaker nanci pelosi visit video ...             0
# 183  first communityampcont social platform base bl...             0
# 196  read care depend breadth experi abil associ of...             0
# 206  user twitter block other mayb follow peopl kno...             4
# 209           csiro dude prop everi question nice done             2
# 210               everytim ai think skynet bloodi movi             2
# 211  crazi idea find much ndi program need plot way...             3
# 213  fire missil water near earlier today provoc th...             3
# 215  soon someon bring idea sun blow wind shine bla...             0
# 216  peopl twitter delet tweet tweet twitter retwee...             2
# 217     cours guy tie uranium flog nuclear power plant             4
# 218  use gaslit keep expect politician samegreat po...             2

# %% [markdown]
# ## Topic extraction with LDA (Latent Dirichlet Allocation) with Tf-IDF

# %%
LDA_tfidf = LatentDirichletAllocation(n_components=5,random_state=42)
LDA_tfidf.fit(tfidf_tweet)
# Out:
# LatentDirichletAllocation(n_components=5, random_state=42)

# %%
LDA_tfidf.components_
# Out:
# array([[0.31629926, 0.31629926, 0.31629926, ..., 0.20001241, 0.20001241,
#         0.3424744 ],
#        [0.20001054, 0.20001054, 0.20001054, ..., 0.20001192, 0.20001192,
#         0.20001076],
#        [0.20001087, 0.20001087, 0.20001087, ..., 0.37306855, 0.37306855,
#         0.20001154],
#        [0.2000109 , 0.2000109 , 0.2000109 , ..., 0.20001227, 0.20001227,
#         0.2000112 ],
#        [0.20001079, 0.20001079, 0.20001079, ..., 0.20001191, 0.20001191,
#         0.20001088]])

# %%
eachtopics = LDA_tfidf.components_[0]
eachtopics.argsort()
# Out:
# array([ 879,  301,  216, ..., 5539,  530, 6516], dtype=int64)

# %%
#eachtopics[183]
# Top 5 words for this topic:
eachtopics.argsort()[-5:]
# Out:
# array([1046, 6519, 5539,  530, 6516], dtype=int64)

# %%
for index,topic in enumerate(LDA_tfidf.components_):
    print(f'Most prevalent topic #{index}'+ ': ')
    print([tfidf.get_feature_names()[i] for i in topic.argsort()[-10:]])
# Out:
# Most prevalent topic #0:
# ['pelosi', 'land', 'keyword', 'welocom', 'cobb best', 'cobb', 'welcom taiwan', 'taiwan', 'best', 'welcom']
# Most prevalent topic #1:
# ['day', 'learn', 'wait', 'use', 'account', 'love', 'account use shibuyaennithat', 'shibuyaennithat', 'use shibuyaennithat', 'account use']
# Most prevalent topic #2:
# ['chine', 'say', 'china', 'taiwan', 'use', 'account', 'account tweetbot', 'account tweetbot use', 'tweetbot use', 'tweetbot']
# Most prevalent topic #3:
# ['appli', 'wish', 'taiwan', 'fuck', 'life', 'come', 'happen', 'hello twittbot', 'twittbot', 'hello']
# Most prevalent topic #4:
# ['friend', 'forc', 'click link bio', 'click', 'click link', 'link bio', 'bio', 'link', 'twitter', 'taiwan']

# %%
topic_lda_tfidf = LDA_tfidf.transform(tfidf_tweet)
topic_lda_tfidf.shape
topic_lda_tfidf[0].round(2)
topic_lda_tfidf[0].argmax()
topic_lda_tfidf.argmax(axis=1)
# Out:
# array([0, 3, 2, 1, 4, 2, 2, 2, 0, 0, 4, 2, 4, 0, 3, 3, 3, 2, 4, 0, 4, 3,
#        4, 4, 2, 1, 4, 2, 0, 0, 0, 4, 4, 3, 1, 3, 1, 4, 4, 2, 3, 2, 4, 2,
#        3, 1, 3, 2, 1, 4, 3, 1, 1, 2, 2, 1, 1, 3, 1, 3, 4, 1, 3, 1, 4, 4,
#        4, 4, 4, 4, 0, 3, 0, 4, 0, 4, 2, 2, 0, 0, 2, 1, 2, 2, 0, 4, 3, 1,
#        1, 2, 1, 0, 3, 0, 3, 3, 3, 3, 2, 3, 2, 3, 1, 1, 2, 2, 2, 3, 1, 1,
#        4, 3, 4, 4, 2, 1, 0, 2, 2, 4, 2, 1, 4, 3, 1, 2, 3, 0, 1, 0, 2, 4,
#        3, 2, 2, 3, 4, 3, 4, 4, 0, 4, 1, 1, 1, 1, 3, 0, 2, 0, 0, 4, 1, 0,
#        1, 1, 3, 4, 3, 0, 1, 1, 3, 3, 0, 0, 1, 2, 3, 3, 4, 1, 3, 0, 3, 2,
#        2, 4, 1, 4, 0, 2, 4, 3, 4, 1, 0, 4, 0, 1, 1, 0, 0, 3, 1, 3, 0, 4,
#        1, 4, 4, 1, 3, 0, 0, 2, 4, 1, 1, 4, 2, 1, 2, 0, 3, 3, 2, 3, 0, 2,
#        4, 0, 0, 3, 4, 4, 4, 1, 4, 2, 3, 4, 3, 1, 3, 0, 4, 0, 1, 1, 0, 4,
#        1, 1, 1, 3, 2, 1, 3, 1, 0, 1, 4, 2, 1, 1, 2, 1, 3, 1, 1, 1, 4, 2,
#        4, 4, 0, 1, 4, 3, 2, 1, 0, 2, 4, 1, 4, 3, 2, 3, 3, 1, 3, 1, 4, 0,
#        0, 0, 0, 1, 2, 3, 1], dtype=int64)

# %%
df['Topic_lda_tfif'] = topic_lda_tfidf.argmax(axis=1)
df[['tweet','cleaned_tweet','Topic_lda_tfif']].head(40)
# Out:
#                                                  tweet  \
# 4    1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9    Musk says that that the only two publicly trad...
# 11   This account is Tweetbot, I don't use it. #Twe...
# 16   #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17   #tesla #TSLA Musk says there’s still a “host o...
# 18   #TSLA #Tesla Musk says that the Model Y is tra...
# 19   #tesla #TSLA Elon Musk is now on stage and say...
# 20   #tesla #TSLA Viecha announces preliminary resu...
# 21   #tesla #TSLA Tesla Holders Approve 3-to-1 Stoc...
# 27   🌞☕️👩🏻‍💻\nMornings are for coffee and coding.\n...
# 28   #tesla #TSLA Proposal 8 requests that Tesla re...
# 29   #tesla #TSLA “Let’s cut the bull,” McRitchie s...
# 30   #tesla #TSLA Martin Viecha is now officially c...
# 32   #tesla #TSLA Denholm says that “good governanc...
# 34   #tesla #TSLA Denholm is stressing that Tesla u...
# 35   Tesla Inc Viecha says Musk will give a “presen...
# 48   Whatever can happen at any time can happen tod...
# 54   China wants to annex Taiwan and yet Chinese go...
# 65   #BREAKING: JUST IN - China flew its drones (BZ...
# 68   Need tackle VIPER today for the first time…goo...
# 69   #Android #Twitter When the preferred language ...
# 76   The conflict is it a game between #China and #...
# 83   #NewProfilePic ✌️😎✅ Co-gather our amazing #NFT...
# 84   #blocked An international friend on Twitter ha...
# 109  Enjoyed chatting with @chrislindsay_ and @BBCN...
# 133  Responding to mounting public concern on wheth...
# 137  BREAKING -- #Taiwan says fired flares to drive...
# 152  This year marks the 27th year of my language l...
# 164  Prior to US House Speaker Nancy Pelosi’s visit...
# 183  #rootmeta the first Community&amp;amp;Content ...
# 196  Reading w/ care depends on your breadth of exp...
# 206  #blocked Why do some users on Twitter block ot...
# 209  Does the CSIRO dude have a prop for every ques...
# 210  Everytime I here AI, I think of Skynet. Bloody...
# 211  Here's a crazy idea. Find out how much $ NDIS ...
# 213  #China fired missiles into the waters near #Ta...
# 215  How soon before someone brings the idea, "when...
# 216  #Twitter #Tweets Why are some people on Twitte...
# 217  Of course, the guy who has ties to Uranium wil...
# 218  I'm so used to being gaslit, that I keep expec...
#
#                                          cleaned_tweet  Topic_lda_tfif
# 4    sheesherc kingmessiahbsc bro coin respectfli l...               0
# 9    musk say two publicli trade secur own tesla tw...               3
# 11                                account tweetbot use               2
# 16   ultim think end build gigafactori musk say cla...               1
# 17   musk say still host problem left solv spool au...               4
# 18   musk say model track tesla highestsel vehicl r...               2
# 19   elon musk stage say tesla might get close mill...               2
# 20   viecha announc preliminari result stock split ...               2
# 21      tesla holder approv stock split sharehold meet               0
# 27                                     morn coffe code               0
# 28   propos request tesla report effort enhanc boar...               4
# 29   let cut bull mcritchi say proxi access long ov...               2
# 30   martin viecha offici call meet order peopl alr...               4
# 32   denholm say good govern hallmark sustain menti...               0
# 34   denholm stress tesla use le water factori auto...               3
# 35   tesla inc viecha say musk give present propos ...               3
# 48                     whatev happen time happen today               3
# 54   china want annex taiwan yet chine gov often sp...               2
# 65   china flew drone around japan sakishima island...               4
# 68         need tackl viper today first time good luck               0
# 69   prefer languag twitter android client simplifi...               4
# 76   conflict game poor toyand taiwanes wait player...               3
# 83      cogath amaz elrondcombey fundament chang nftac               4
# 84   intern friend twitter block almost month inter...               4
# 109                          enjoy chat develop situat               2
# 133  respond mount public concern whether chine mis...               1
# 137  break say fire flare drive away four drone kin...               4
# 152  year mark year languag learn effort learn stil...               2
# 164  prior u hous speaker nanci pelosi visit video ...               0
# 183  first communityampcont social platform base bl...               0
# 196  read care depend breadth experi abil associ of...               0
# 206  user twitter block other mayb follow peopl kno...               4
# 209           csiro dude prop everi question nice done               4
# 210               everytim ai think skynet bloodi movi               3
# 211  crazi idea find much ndi program need plot way...               1
# 213  fire missil water near earlier today provoc th...               3
# 215  soon someon bring idea sun blow wind shine bla...               1
# 216  peopl twitter delet tweet tweet twitter retwee...               4
# 217     cours guy tie uranium flog nuclear power plant               4
# 218  use gaslit keep expect politician samegreat po...               2

# %% [markdown]
# ## Topic extraction with NMF (Non-Negative Matric Factorization) with Countvectorizer

# %%
nmf_model_cv = NMF(n_components=5, random_state=42) 
nmf_model_cv.fit(countv_tweet)
# Out:
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate(nmf_model_cv.components_):
    print(f'Most prevalent topic #{index}'+ ': ')
    print([countv.get_feature_names()[i] for i in topic.argsort()[-10:]])
# Out:
# Most prevalent topic #0:
# ['pelosi', 'close', 'sourc', 'missil', 'militari', 'visit', 'ministri', 'chine', 'china', 'taiwan']
# Most prevalent topic #1:
# ['twitter follow', 'remov', 'thailand', 'block twitter', 'intern friend', 'intern', 'block', 'follow', 'friend', 'twitter']
# Most prevalent topic #2:
# ['look', 'appli job', 'job like', 'like', 'amd', 'link bio', 'link', 'bio', 'job', 'appli']
# Most prevalent topic #3:
# ['job like', 'track', 'want', 'right', 'job', 'look', 'use', 'like', 'manag', 'keyword']
# Most prevalent topic #4:
# ['ministri', 'visit', 'tue', 'late tue', 'cyber', 'cyber attack', 'receiv', 'late', 'say', 'attack']

# %%
topic_nmf_cv = nmf_model_cv.transform(countv_tweet)
topic_nmf_cv.argmax(axis=1)
df['Topic_nmf_cv'] = topic_nmf_cv.argmax(axis=1)
df[['tweet','cleaned_tweet','Topic_nmf_cv']].head(40)
# Out:
#                                                  tweet  \
# 4    1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9    Musk says that that the only two publicly trad...
# 11   This account is Tweetbot, I don't use it. #Twe...
# 16   #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17   #tesla #TSLA Musk says there’s still a “host o...
# 18   #TSLA #Tesla Musk says that the Model Y is tra...
# 19   #tesla #TSLA Elon Musk is now on stage and say...
# 20   #tesla #TSLA Viecha announces preliminary resu...
# 21   #tesla #TSLA Tesla Holders Approve 3-to-1 Stoc...
# 27   🌞☕️👩🏻‍💻\nMornings are for coffee and coding.\n...
# 28   #tesla #TSLA Proposal 8 requests that Tesla re...
# 29   #tesla #TSLA “Let’s cut the bull,” McRitchie s...
# 30   #tesla #TSLA Martin Viecha is now officially c...
# 32   #tesla #TSLA Denholm says that “good governanc...
# 34   #tesla #TSLA Denholm is stressing that Tesla u...
# 35   Tesla Inc Viecha says Musk will give a “presen...
# 48   Whatever can happen at any time can happen tod...
# 54   China wants to annex Taiwan and yet Chinese go...
# 65   #BREAKING: JUST IN - China flew its drones (BZ...
# 68   Need tackle VIPER today for the first time…goo...
# 69   #Android #Twitter When the preferred language ...
# 76   The conflict is it a game between #China and #...
# 83   #NewProfilePic ✌️😎✅ Co-gather our amazing #NFT...
# 84   #blocked An international friend on Twitter ha...
# 109  Enjoyed chatting with @chrislindsay_ and @BBCN...
# 133  Responding to mounting public concern on wheth...
# 137  BREAKING -- #Taiwan says fired flares to drive...
# 152  This year marks the 27th year of my language l...
# 164  Prior to US House Speaker Nancy Pelosi’s visit...
# 183  #rootmeta the first Community&amp;amp;Content ...
# 196  Reading w/ care depends on your breadth of exp...
# 206  #blocked Why do some users on Twitter block ot...
# 209  Does the CSIRO dude have a prop for every ques...
# 210  Everytime I here AI, I think of Skynet. Bloody...
# 211  Here's a crazy idea. Find out how much $ NDIS ...
# 213  #China fired missiles into the waters near #Ta...
# 215  How soon before someone brings the idea, "when...
# 216  #Twitter #Tweets Why are some people on Twitte...
# 217  Of course, the guy who has ties to Uranium wil...
# 218  I'm so used to being gaslit, that I keep expec...
#
#                                          cleaned_tweet  Topic_nmf_cv
# 4    sheesherc kingmessiahbsc bro coin respectfli l...             3
# 9    musk say two publicli trade secur own tesla tw...             1
# 11                                account tweetbot use             3
# 16   ultim think end build gigafactori musk say cla...             4
# 17   musk say still host problem left solv spool au...             4
# 18   musk say model track tesla highestsel vehicl r...             4
# 19   elon musk stage say tesla might get close mill...             4
# 20   viecha announc preliminari result stock split ...             0
# 21      tesla holder approv stock split sharehold meet             4
# 27                                     morn coffe code             0
# 28   propos request tesla report effort enhanc boar...             4
# 29   let cut bull mcritchi say proxi access long ov...             4
# 30   martin viecha offici call meet order peopl alr...             2
# 32   denholm say good govern hallmark sustain menti...             4
# 34   denholm stress tesla use le water factori auto...             3
# 35   tesla inc viecha say musk give present propos ...             4
# 48                     whatev happen time happen today             0
# 54   china want annex taiwan yet chine gov often sp...             0
# 65   china flew drone around japan sakishima island...             0
# 68         need tackl viper today first time good luck             0
# 69   prefer languag twitter android client simplifi...             1
# 76   conflict game poor toyand taiwanes wait player...             4
# 83      cogath amaz elrondcombey fundament chang nftac             1
# 84   intern friend twitter block almost month inter...             1
# 109                          enjoy chat develop situat             0
# 133  respond mount public concern whether chine mis...             4
# 137  break say fire flare drive away four drone kin...             4
# 152  year mark year languag learn effort learn stil...             4
# 164  prior u hous speaker nanci pelosi visit video ...             4
# 183  first communityampcont social platform base bl...             1
# 196  read care depend breadth experi abil associ of...             4
# 206  user twitter block other mayb follow peopl kno...             1
# 209           csiro dude prop everi question nice done             0
# 210               everytim ai think skynet bloodi movi             4
# 211  crazi idea find much ndi program need plot way...             4
# 213  fire missil water near earlier today provoc th...             0
# 215  soon someon bring idea sun blow wind shine bla...             2
# 216  peopl twitter delet tweet tweet twitter retwee...             1
# 217     cours guy tie uranium flog nuclear power plant             1
# 218  use gaslit keep expect politician samegreat po...             3

# %% [markdown]
# ## Topic extraction with NMF (Non-Negative Matric Factorization) with Tf-IDF

# %%
nmf_model_tfidf= NMF(n_components = 5, random_state=42)
nmf_model_tfidf.fit(tfidf_tweet)
# Out:
# NMF(n_components=5, random_state=42)

# %%
for index,topic in enumerate(nmf_model_tfidf.components_):
    print(f'Most prevalent topic #{index}'+ ': ')
    print([tfidf.get_feature_names()[i] for i in topic.argsort()[-10:]])
# Out:
# Most prevalent topic #0:
# ['twitter account', 'specif', 'twitter', 'keyword', 'use', 'account', 'tweetbot use', 'tweetbot', 'account tweetbot use', 'account tweetbot']
# Most prevalent topic #1:
# ['greater harmoni', 'destin greater harmoni', 'destin greater', 'destin', 'harmoni', 'happen destin', 'love happen destin', 'happen destin greater', 'love', 'happen']
# Most prevalent topic #2:
# ['manag', 'look', 'like', 'job like', 'amd', 'bio', 'link', 'link bio', 'appli', 'job']
# Most prevalent topic #3:
# ['twitter account', 'specif', 'twitter', 'keyword', 'use', 'account', 'account use', 'shibuyaennithat', 'use shibuyaennithat', 'account use shibuyaennithat']
# Most prevalent topic #4:
# ['navi', 'ministri', 'pelosi', 'china', 'chine', 'arriv', 'arriv welcom', 'taiwan', 'welcom taiwan', 'welcom']

# %%
topic_nmf_tfidf = nmf_model_tfidf.transform(tfidf_tweet)
topic_nmf_tfidf.argmax(axis=1)
df['Topics_nmf_tfidf'] = topic_nmf_tfidf.argmax(axis=1)
df[['tweet','cleaned_tweet','Topics_nmf_tfidf']].head(40)
# Out:
#                                                  tweet  \
# 4    1goonrich Sheesherc KingMessiah_BSC #kingmessi...
# 9    Musk says that that the only two publicly trad...
# 11   This account is Tweetbot, I don't use it. #Twe...
# 16   #Tesla #TSLA “Ultimately I think we’ll end up ...
# 17   #tesla #TSLA Musk says there’s still a “host o...
# 18   #TSLA #Tesla Musk says that the Model Y is tra...
# 19   #tesla #TSLA Elon Musk is now on stage and say...
# 20   #tesla #TSLA Viecha announces preliminary resu...
# 21   #tesla #TSLA Tesla Holders Approve 3-to-1 Stoc...
# 27   🌞☕️👩🏻‍💻\nMornings are for coffee and coding.\n...
# 28   #tesla #TSLA Proposal 8 requests that Tesla re...
# 29   #tesla #TSLA “Let’s cut the bull,” McRitchie s...
# 30   #tesla #TSLA Martin Viecha is now officially c...
# 32   #tesla #TSLA Denholm says that “good governanc...
# 34   #tesla #TSLA Denholm is stressing that Tesla u...
# 35   Tesla Inc Viecha says Musk will give a “presen...
# 48   Whatever can happen at any time can happen tod...
# 54   China wants to annex Taiwan and yet Chinese go...
# 65   #BREAKING: JUST IN - China flew its drones (BZ...
# 68   Need tackle VIPER today for the first time…goo...
# 69   #Android #Twitter When the preferred language ...
# 76   The conflict is it a game between #China and #...
# 83   #NewProfilePic ✌️😎✅ Co-gather our amazing #NFT...
# 84   #blocked An international friend on Twitter ha...
# 109  Enjoyed chatting with @chrislindsay_ and @BBCN...
# 133  Responding to mounting public concern on wheth...
# 137  BREAKING -- #Taiwan says fired flares to drive...
# 152  This year marks the 27th year of my language l...
# 164  Prior to US House Speaker Nancy Pelosi’s visit...
# 183  #rootmeta the first Community&amp;amp;Content ...
# 196  Reading w/ care depends on your breadth of exp...
# 206  #blocked Why do some users on Twitter block ot...
# 209  Does the CSIRO dude have a prop for every ques...
# 210  Everytime I here AI, I think of Skynet. Bloody...
# 211  Here's a crazy idea. Find out how much $ NDIS ...
# 213  #China fired missiles into the waters near #Ta...
# 215  How soon before someone brings the idea, "when...
# 216  #Twitter #Tweets Why are some people on Twitte...
# 217  Of course, the guy who has ties to Uranium wil...
# 218  I'm so used to being gaslit, that I keep expec...
#
#                                          cleaned_tweet  Topics_nmf_tfidf
# 4    sheesherc kingmessiahbsc bro coin respectfli l...                 2
# 9    musk say two publicli trade secur own tesla tw...                 2
# 11                                account tweetbot use                 0
# 16   ultim think end build gigafactori musk say cla...                 4
# 17   musk say still host problem left solv spool au...                 4
# 18   musk say model track tesla highestsel vehicl r...                 4
# 19   elon musk stage say tesla might get close mill...                 4
# 20   viecha announc preliminari result stock split ...                 4
# 21      tesla holder approv stock split sharehold meet                 4
# 27                                     morn coffe code                 4
# 28   propos request tesla report effort enhanc boar...                 4
# 29   let cut bull mcritchi say proxi access long ov...                 4
# 30   martin viecha offici call meet order peopl alr...                 2
# 32   denholm say good govern hallmark sustain menti...                 4
# 34   denholm stress tesla use le water factori auto...                 3
# 35   tesla inc viecha say musk give present propos ...                 2
# 48                     whatev happen time happen today                 1
# 54   china want annex taiwan yet chine gov often sp...                 4
# 65   china flew drone around japan sakishima island...                 4
# 68         need tackl viper today first time good luck                 4
# 69   prefer languag twitter android client simplifi...                 4
# 76   conflict game poor toyand taiwanes wait player...                 4
# 83      cogath amaz elrondcombey fundament chang nftac                 4
# 84   intern friend twitter block almost month inter...                 2
# 109                          enjoy chat develop situat                 2
# 133  respond mount public concern whether chine mis...                 4
# 137  break say fire flare drive away four drone kin...                 4
# 152  year mark year languag learn effort learn stil...                 4
# 164  prior u hous speaker nanci pelosi visit video ...                 4
# 183  first communityampcont social platform base bl...                 2
# 196  read care depend breadth experi abil associ of...                 4
# 206  user twitter block other mayb follow peopl kno...                 2
# 209           csiro dude prop everi question nice done                 4
# 210               everytim ai think skynet bloodi movi                 4
# 211  crazi idea find much ndi program need plot way...                 4
# 213  fire missil water near earlier today provoc th...                 4
# 215  soon someon bring idea sun blow wind shine bla...                 2
# 216  peopl twitter delet tweet tweet twitter retwee...                 2
# 217     cours guy tie uranium flog nuclear power plant                 1
# 218  use gaslit keep expect politician samegreat po...                 3
